# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import math
import statsmodels.api as sm
# Out:
# /Users/scott/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import sys
import os.path
sys.path.append(os.path.abspath(os.path.dirname(os.getcwd())))
import util

# %%
df, df_shops, df_ingredients = util.load_burritos()
df.tail()
# Out:
#                           Location        Burrito       Date  Cost  Hunger  \
# 333        valentines mexican food    carne asada   8/7/2017  6.75     4.0
# 334               vallarta express     california   8/9/2017  8.35     4.5
# 335  roberto's taco shop hillcrest     california  8/14/2017  7.00     4.0
# 336                      kotija jr     california  8/19/2017  6.99     4.0
# 337                      kotija jr  steak fajitas  8/19/2017  7.10     3.0
#
#      Mass (g)  Density (g/mL)  Length  Circum  Volume  ...    Fillings  \
# 333       NaN             NaN    19.5    21.0    0.68  ...         3.5
# 334       NaN             NaN    21.0    23.0    0.88  ...         3.0
# 335       NaN             NaN    19.5    21.5    0.72  ...         4.0
# 336     550.0        0.785714    20.0    21.0    0.70  ...         3.8
# 337       NaN             NaN    21.0    22.0    0.81  ...         4.0
#
#      Meat:filling  Uniformity  Salsa  Synergy  Wrap  overall  Rec  Reviewer  \
# 333           4.5        4.50   3.00      3.5   4.0      3.9  NaN     scott
# 334           4.0        2.50   4.00      4.5   4.0      4.1  NaN     scott
# 335           4.0        3.70   3.80      4.6   4.8      4.2  NaN     simon
# 336           3.0        2.50   3.30      4.0   5.0      3.7  NaN     scott
# 337           4.5        4.75   3.75      4.0   5.0      4.2  NaN     emily
#
#      Notes
# 333    NaN
# 334    NaN
# 335    NaN
# 336    NaN
# 337    NaN
#
# [5 rows x 23 columns]
